# %% [markdown]
# <a href="https://colab.research.google.com/github/mahajanprachii/Laptop-price-tracker/blob/main/volality.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = yf.download("^NSEI", period="3y")
# Out:
# /tmp/ipykernel_1835/1883291139.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("^NSEI", period="3y")
# [*********************100%***********************]  1 of 1 completed

# %%
df['Log_Return'] = np.log(df['Close'] / df['Close'].shift(1))

# %%
df['Rolling_Volatility'] = df['Log_Return'].rolling(window=30).std()

# %%
plt.figure(figsize=(12,3
                    ))

plt.plot(
    df.index,
    df['Rolling_Volatility']
)

plt.title("30-Day Rolling Volatility of NIFTY 50")
plt.xlabel("Date")
plt.ylabel("Volatility")

plt.show()
